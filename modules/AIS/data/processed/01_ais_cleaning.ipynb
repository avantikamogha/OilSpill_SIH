# %%
import os

# 1. Check exactly where your notebook is running from
print("Current folder:", os.getcwd())

# 2. List all files in your target data directory to see what is actually there
print("Files in ../data/:", os.listdir("../data/"))
# Out:
# Current folder: c:\Users\Aashna\Desktop\SIH_2026\OilSpill_SIH\modules\AIS\data\processed
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[1], line 7
#       3 # 1. Check exactly where your notebook is running from
#       4 print("Current folder:", os.getcwd())
#       5
#       6 # 2. List all files in your target data directory to see what is actually there
# ----> 7 print("Files in ../data/:", os.listdir("../data/"))
#
# FileNotFoundError: [WinError 3] The system cannot find the path specified: '../data/'

# %%
import pandas as pd

df = pd.read_csv("ais_clean.csv")
